# %% [markdown]
# <hr style="height:10px">
#
# <div class='container2'>
# 		<div>
# 			<img src='images\header.png' ALIGN='left' style='width:10em'>
# 		</div>
# 	<div style='padding: 0 7em 2em 12em;'>
# 	<h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
#     <div style="font-size:12pt;float:left;"><b>Projetos de Inteligência Artificial</b></div>
# 	</div>
# </div>
#
#
#  <hr style="height:5px">
#
#
# <h2>Introdução ao Ambiente de Projetos - Python</h2>
#
#
#
#  <hr style="height:2px">

# %%
from platform import python_version
print(f'A versão em uso é {python_version()}.')
# Out:
# A versão em uso é 3.10.13.

# %%
python_version()
# Out:
# '3.10.13'

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %% [markdown]
# #### Operadores Aritméticos

# %%
# Adição
1 + 5
# Out:
# 6

# %%
# Subtração
3 - 2
# Out:
# 1

# %%
# Multiplicação
16 * 3
# Out:
# 48

# %%
# Divisão
6/ 3
# Out:
# 2.0

# %%
# Potência
4 ** 3
# Out:
# 64

# %%
# Módulo (resto da divisão)
100 % 7
# Out:
# 2

# %% [markdown]
# #### Tipo de Dados (Type)

# %%
# Qual o tipo do (?) -> Inteiro
type(5)
# Out:
# int

# %%
# Qual o tipo do (?) -> Float - Decimal
type(5.0)
# Out:
# float

# %%
# Qual o tipo do (?) -> String
a = 'Estudando Python!'
type(a)
# Out:
# str

# %% [markdown]
# #### Condicional if

# %%
# Condicional if (Se)
if 5 > 2:
    print("A sentença é verdadeira!")
# Out:
# A sentença é verdadeira!

# %%
# Condicional if...else
if 5 < 2:
    print("A sentença é verdadeira!")
else:
    print("A sentença é falsa!")
# Out:
# A sentença é falsa!

# %%
# Condicional if...else com variável
dia = "segunda-feira"
if dia == "Sexta-feira":
    print("Hoje nevará!")
else:
    print("Hoje vai gear!")
# Out:
# Hoje vai gear!

# %% [markdown]
# #### Manipulando arquivos

# %% [markdown]
# #### Lendo arquivos (.txt)

# %%
# Abrindo o arquivo para leitura
a1 = open("arquivos/arquivo1.txt", "r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Abrindo o arquivo para leitura
# ----> 2 a1 = open("arquivos/arquivo1.txt", "r")
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'arquivos/arquivo1.txt'

# %%
# Lendo o arquivo
print(a1.read())
# Out:
# Seja bem-vindo em LIA1 - 2024/1 - 25/03!

# %% [markdown]
# #### Gravando arquivos (.txt)

# %%
# Abrindo o arquivo para gravação
a2 = open("arquivos/arquivo2.txt", "w")

# %%
# Gravando no arquivo
a2.write("Aprendendo Python em 2024/1 ao som de um cortador de grama!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Gravando no arquivo
# ----> 2 a2.write("Aprendendo Python em 2024/1 ao som de um cortador de grama!")
#
# NameError: name 'a2' is not defined

# %%
# Abrindo o arquivo para leitura
a2 = open("arquivos/arquivo2.txt", "r")

# %%
# Imprimindo arquivo
print(a2.read())
# Out:
# Aprendendo Python em 2024/1 ao som de um cortador de grama!
